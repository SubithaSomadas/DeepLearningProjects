# %%
import tensorflow as tf
from tensorflow.keras import layers,models
import matplotlib.pyplot as plt
from IPython.display import HTML
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import numpy as np

# %%
from PIL import Image

# %%
im = Image.open("C:/Users/Subitha/Desktop/DL/1.jpg")

# %%
im.width, im.height, im.mode, im.format, type(im)
# Out:
# (2592, 3240, 'RGB', 'JPEG', PIL.JpegImagePlugin.JpegImageFile)

# %%
img = im.resize((256,256), Image.BILINEAR)

# %%
img.width, img.height, img.mode, img.format, type(img)
# Out:
# (256, 256, 'RGB', None, PIL.Image.Image)

# %%
img_arr=[]

# %%
img_arr.append(np.asarray(img))

# %%
len(img_arr)
# Out:
# 1

# %%
img_arr[0].shape
# Out:
# (256, 256, 3)

# %%
image_array = np.reshape(img_arr,(len(img_arr),256,256,3))

# %%
image_array.shape
# Out:
# (1, 256, 256, 3)

# %%
IMAGE_SIZE = 256
CHANNELS = 3

# %% [markdown]
# # Build Model

# %%
model = models.Sequential([
    
    layers.Conv2D(32, kernel_size = (3,3), activation='relu',padding='same',input_shape = input_shape),
    layers.MaxPooling2D((2, 2)),    
    layers.Conv2D(8,  kernel_size = (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(8,  kernel_size = (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D((2, 2)),
    layers.Conv2D(8,  kernel_size = (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D((2, 2)),
    
    
    
    layers.Conv2D(8, (3, 3), activation='relu',padding='same'),
    layers.UpSampling2D((2, 2)),
    layers.Conv2D(8, (3, 3), activation='relu',padding='same'),
    layers.UpSampling2D((2, 2)),
    layers.Conv2D(8, (3, 3), activation='relu',padding='same'),
    layers.UpSampling2D((2, 2)),
    layers.Conv2D(3, (3, 3), activation='relu',padding='same'),
    layers.UpSampling2D((2, 2)),
])

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_82 (Conv2D)          (None, 256, 256, 32)      896
#
#  max_pooling2d_41 (MaxPoolin  (None, 128, 128, 32)     0
#  g2D)
#
#  conv2d_83 (Conv2D)          (None, 128, 128, 8)       2312
#
#  max_pooling2d_42 (MaxPoolin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_84 (Conv2D)          (None, 64, 64, 8)         584
#
#  max_pooling2d_43 (MaxPoolin  (None, 32, 32, 8)        0
#  g2D)
#
#  conv2d_85 (Conv2D)          (None, 32, 32, 8)         584
#
#  max_pooling2d_44 (MaxPoolin  (None, 16, 16, 8)        0
#  g2D)
#
#  conv2d_86 (Conv2D)          (None, 16, 16, 8)         584
#
#  up_sampling2d_43 (UpSamplin  (None, 32, 32, 8)        0
#  g2D)
#
#  conv2d_87 (Conv2D)          (None, 32, 32, 8)         584
#
#  up_sampling2d_44 (UpSamplin  (None, 64, 64, 8)        0
#  g2D)
#
# ...

# %% [markdown]
# # Compiling the Model

# %%
model.compile(optimizer='adam',loss='mean_squared_error', metrics=['accuracy'])

# %%
history = model.fit(image_array,image_array,epochs=2000,shuffle=True)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 1s 837ms/step - loss: 26221.0254 - accuracy: 0.7171
# Epoch 2/2000
# 1/1 [==============================] - 0s 62ms/step - loss: 26102.6328 - accuracy: 0.7046
# Epoch 3/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 25889.7988 - accuracy: 0.6974
# Epoch 4/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 25558.5781 - accuracy: 0.6976
# Epoch 5/2000
# 1/1 [==============================] - 0s 65ms/step - loss: 25075.9688 - accuracy: 0.7022
# Epoch 6/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 24386.8594 - accuracy: 0.7089
# Epoch 7/2000
# 1/1 [==============================] - 0s 64ms/step - loss: 23440.5410 - accuracy: 0.7145
# Epoch 8/2000
# 1/1 [==============================] - 0s 70ms/step - loss: 22219.2188 - accuracy: 0.7228
# Epoch 9/2000
# 1/1 [==============================] - 0s 60ms/step - loss: 20736.5391 - accuracy: 0.7358
# Epoch 10/2000
# ...

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize =(15,8))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'])
plt.title('Accuracy')
plt.subplot(1,2,2)
plt.plot(history.history['loss'])
plt.title('Loss')
plt.show()

# %%
pred = model.predict(image_array)
# Out:
# 1/1 [==============================] - 0s 95ms/step

# %%
im = Image.fromarray(np.uint8(pred[0].reshape(256,256,3)))

# %%
im.show()
